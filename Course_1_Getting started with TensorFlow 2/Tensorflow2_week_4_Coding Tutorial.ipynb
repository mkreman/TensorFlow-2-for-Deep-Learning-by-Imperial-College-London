# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# # Saving and loading models

# %% [markdown]
#  ## Coding tutorials
#  #### [1. Saving and loading model weights](#coding_tutorial_1)
#  #### [2. Model saving criteria](#coding_tutorial_2)
#  #### [3. Saving the entire model](#coding_tutorial_3)
#  #### [4. Loading pre-trained Keras models](#coding_tutorial_4)
#  #### [5. Tensorflow Hub modules](#coding_tutorial_5)

# %% [markdown]
# ***
# <a id="coding_tutorial_1"></a>
# ## Saving and loading model weights

# %% [markdown]
# #### Load and inspect CIFAR-10 dataset

# %% [markdown]
# The CIFAR-10 dataset consists of, in total, 60000 color images, each with one of 10 labels: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck. For an introduction and a download, see [this link](https://www.cs.toronto.edu/~kriz/cifar.html).

# %%
# Import the CIFAR-10 dataset and rescale the pixel values

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0

# Use smaller subset -- speeds things up
x_train = x_train[:10000]
y_train = y_train[:10000]
x_test = x_test[:1000]
y_test = y_test[:1000]

# %%
# Plot the first 10 CIFAR-10 images

import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 10, figsize=(10, 1))
for i in range(10):
    ax[i].set_axis_off()
    ax[i].imshow(x_train[i])

# %% [markdown]
# #### Introduce two useful functions

# %%
# Introduce function to test model accuracy

def get_test_accuracy(model, x_test, y_test):
    test_loss, test_acc = model.evaluate(x=x_test, y=y_test, verbose=0)
    print('accuracy: {acc:0.3f}'.format(acc=test_acc))

# %%
# Introduce function that creates a new instance of a simple CNN

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D

def get_new_model():
    model = Sequential([
        Conv2D(filters=16, input_shape=(32, 32, 3), kernel_size=(3, 3), 
               activation='relu', name='conv_1'),
        Conv2D(filters=8, kernel_size=(3, 3), activation='relu', name='conv_2'),
        MaxPooling2D(pool_size=(4, 4), name='pool_1'),
        Flatten(name='flatten'),
        Dense(units=32, activation='relu', name='dense_1'),
        Dense(units=10, activation='softmax', name='dense_2')
    ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %% [markdown]
# #### Create simple convolutional neural network classifier

# %%
# Create an instance of the model and show model summary
model = get_new_model()
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1 (Conv2D)              (None, 30, 30, 16)        448
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 28, 28, 8)         1160
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 7, 7, 8)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 392)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                12576
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 14,514
# Trainable params: 14,514
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Test accuracy of the untrained model, around 10% (random)

get_test_accuracy(model, x_test, y_test)
# Out:
# accuracy: 0.077

# %% [markdown]
# #### Train model with checkpoints

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# Create Tensorflow checkpoint object
checkpoint_path = 'models_checkpoints/checkpoint'
checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                             save_freq='epoch',
                             save_weights_only=True,
                             verbose=1)

# %%
# Fit model, with simple checkpoint which saves (and overwrites) model weights every epoch
model.fit(x=x_train,
          y=y_train,
          epochs=3,
          callbacks=[checkpoint])
# Out:
# Epoch 1/3
# 313/313 [==============================] - 11s 32ms/step - loss: 1.9794 - accuracy: 0.2754
#
# Epoch 00001: saving model to models_checkpoints/checkpoint
# Epoch 2/3
# 313/313 [==============================] - 10s 32ms/step - loss: 1.6278 - accuracy: 0.4114
#
# Epoch 00002: saving model to models_checkpoints/checkpoint
# Epoch 3/3
# 313/313 [==============================] - 10s 32ms/step - loss: 1.5205 - accuracy: 0.4485
#
# Epoch 00003: saving model to models_checkpoints/checkpoint

# %%
# Have a look at what the checkpoint creates
! ls -lh models_checkpoints
# Out:
# total 184K
# -rw-r--r-- 1 root root   77 Mar 25 11:21 checkpoint
# -rw-r--r-- 1 root root 174K Mar 25 11:21 checkpoint.data-00000-of-00001
# -rw-r--r-- 1 root root 2.0K Mar 25 11:21 checkpoint.index

# %%
# Evaluate the performance of the trained model
get_test_accuracy(model, x_test, y_test)
# Out:
# accuracy: 0.460

# %% [markdown]
# #### Create new model, load weights

# %%
# Create a new instance of the (initialised) model, accuracy around 10% again
model = get_new_model()
get_test_accuracy(model, x_test, y_test)
# Out:
# accuracy: 0.089

# %%
# Load weights -- accuracy is the same as the trained model
model.load_weights(checkpoint_path)
get_test_accuracy(model, x_test, y_test)
# Out:
# accuracy: 0.460

# %% [markdown]
# #### Clear directory

# %%
! rm -r models_checkpoints

# %% [markdown]
# ***
# <a id="coding_tutorial_2"></a>
# ## Model saving criteria

# %% [markdown]
# #### Create more customised checkpoint

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# Create Tensorflow checkpoint object with epoch and batch details
checkpoint_5000_path = 'model_checkpoints_5000/checkpoint_{epoch:02d}_{batch:04d}'
checkpoint_5000 = ModelCheckpoint(filepath=checkpoint_5000_path, 
                                  save_weights_only=True,
                                  save_freq=5000,
                                  verbose=1)

# %%
# Create and fit model with checkpoint
model = get_new_model()
model.fit(x_train, y_train, epochs=3, validation_data=(x_test, y_test),
          batch_size=10,
          callbacks=[checkpoint_5000])
# Out:
# Epoch 1/3
# 1000/1000 [==============================] - 13s 12ms/step - loss: 2.0481 - accuracy: 0.2281 - val_loss: 1.5966 - val_accuracy: 0.4290
# Epoch 2/3
# 1000/1000 [==============================] - 12s 12ms/step - loss: 1.5249 - accuracy: 0.4549 - val_loss: 1.4899 - val_accuracy: 0.4490
# Epoch 3/3
# 1000/1000 [==============================] - 12s 12ms/step - loss: 1.4083 - accuracy: 0.4847 - val_loss: 1.4420 - val_accuracy: 0.4930

# %%
# Have a look at what the checkpoint creates
# !ls -lh model_checkpoints_5000
# Out:
# ls: cannot access 'model_checkpoint_5000': No such file or directory

# %% [markdown]
# #### Work with model saving criteria

# %%
# Use tiny training and test set -- will overfit!

x_train = x_train[:100]
y_train = y_train[:100]
x_test = x_test[:100]
y_test = y_test[:100]

# %%
# Create a new instance of untrained model
model = get_new_model()

# %%
# Create Tensorflow checkpoint object which monitors the validation accuracy
checkpoint_best_path = 'model_checkpoint_best/chechpoint'
checkpoint_best = ModelCheckpoint(checkpoint_best_path,
                                  save_weights_only=True,
                                  save_freq='epoch',
                                  monitor='val_accuracy',
                                  save_best_only=True,
                                  verbose=1)

# %%
# Fit the model and save only the weights with the highest validation accuracy
history = model.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test),
                    batch_size=10,
                    callbacks=[checkpoint_best],
                    verbose=1)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 35ms/step - loss: 2.3288 - accuracy: 0.0521 - val_loss: 2.3144 - val_accuracy: 0.0600
#
# Epoch 00001: val_accuracy improved from -inf to 0.06000, saving model to model_checkpoint_best/chechpoint
# Epoch 2/50
# 10/10 [==============================] - 0s 19ms/step - loss: 2.2594 - accuracy: 0.1822 - val_loss: 2.3707 - val_accuracy: 0.0600
#
# Epoch 00002: val_accuracy did not improve from 0.06000
# Epoch 3/50
# 10/10 [==============================] - 0s 19ms/step - loss: 2.2456 - accuracy: 0.1686 - val_loss: 2.3951 - val_accuracy: 0.0600
#
# Epoch 00003: val_accuracy did not improve from 0.06000
# Epoch 4/50
# 10/10 [==============================] - 0s 19ms/step - loss: 2.2219 - accuracy: 0.1581 - val_loss: 2.4220 - val_accuracy: 0.0600
#
# Epoch 00004: val_accuracy did not improve from 0.06000
# Epoch 5/50
# 10/10 [==============================] - 0s 19ms/step - loss: 2.2503 - accuracy: 0.1195 - val_loss: 2.3764 - val_accuracy: 0.0600
#
# Epoch 00005: val_accuracy did not improve from 0.06000
# Epoch 6/50
# 10/10 [==============================] - 0s 21ms/step - loss: 2.1580 - accuracy: 0.2111 - val_loss: 2.4347 - val_accuracy: 0.0600
#
# Epoch 00006: val_accuracy did not improve from 0.06000
# Epoch 7/50
# 10/10 [==============================] - 0s 19ms/step - loss: 2.1859 - accuracy: 0.1622 - val_loss: 2.4090 - val_accuracy: 0.0500
#
# Epoch 00007: val_accuracy did not improve from 0.06000
# Epoch 8/50
# 10/10 [==============================] - 0s 20ms/step - loss: 2.1285 - accuracy: 0.2158 - val_loss: 2.3814 - val_accuracy: 0.0500
#
# Epoch 00008: val_accuracy did not improve from 0.06000
# Epoch 9/50
# 10/10 [==============================] - 0s 18ms/step - loss: 2.1474 - accuracy: 0.1325 - val_loss: 2.4333 - val_accuracy: 0.0600
#
# Epoch 00009: val_accuracy did not improve from 0.06000
# Epoch 10/50
# 10/10 [==============================] - 0s 19ms/step - loss: 2.1011 - accuracy: 0.1567 - val_loss: 2.4088 - val_accuracy: 0.0700
#
# Epoch 00010: val_accuracy improved from 0.06000 to 0.07000, saving model to model_checkpoint_best/chechpoint
# Epoch 11/50
# 10/10 [==============================] - 0s 21ms/step - loss: 2.0099 - accuracy: 0.2272 - val_loss: 2.4348 - val_accuracy: 0.0500
#
# Epoch 00011: val_accuracy did not improve from 0.07000
# Epoch 12/50
# 10/10 [==============================] - 0s 20ms/step - loss: 1.9481 - accuracy: 0.2511 - val_loss: 2.3887 - val_accuracy: 0.1000
#
# Epoch 00012: val_accuracy improved from 0.07000 to 0.10000, saving model to model_checkpoint_best/chechpoint
# Epoch 13/50
# 10/10 [==============================] - 0s 20ms/step - loss: 2.0300 - accuracy: 0.2575 - val_loss: 2.3855 - val_accuracy: 0.1500
#
# Epoch 00013: val_accuracy improved from 0.10000 to 0.15000, saving model to model_checkpoint_best/chechpoint
# Epoch 14/50
# 10/10 [==============================] - 0s 19ms/step - loss: 1.9468 - accuracy: 0.2794 - val_loss: 2.3873 - val_accuracy: 0.1400
#
# Epoch 00014: val_accuracy did not improve from 0.15000
# Epoch 15/50
# 10/10 [==============================] - 0s 19ms/step - loss: 1.8327 - accuracy: 0.3880 - val_loss: 2.4042 - val_accuracy: 0.1400
#
# Epoch 00015: val_accuracy did not improve from 0.15000
# Epoch 16/50
# 10/10 [==============================] - 0s 21ms/step - loss: 1.7806 - accuracy: 0.3403 - val_loss: 2.3946 - val_accuracy: 0.1000
#
# Epoch 00016: val_accuracy did not improve from 0.15000
# Epoch 17/50
# 10/10 [==============================] - 0s 19ms/step - loss: 1.6974 - accuracy: 0.4948 - val_loss: 2.5128 - val_accuracy: 0.1400
#
# Epoch 00017: val_accuracy did not improve from 0.15000
# Epoch 18/50
# 10/10 [==============================] - 0s 21ms/step - loss: 1.6507 - accuracy: 0.4481 - val_loss: 2.3580 - val_accuracy: 0.1300
#
# Epoch 00018: val_accuracy did not improve from 0.15000
# Epoch 19/50
# 10/10 [==============================] - 0s 19ms/step - loss: 1.6383 - accuracy: 0.5449 - val_loss: 2.5010 - val_accuracy: 0.0900
#
# Epoch 00019: val_accuracy did not improve from 0.15000
# Epoch 20/50
# 10/10 [==============================] - 0s 19ms/step - loss: 1.4858 - accuracy: 0.4874 - val_loss: 2.4021 - val_accuracy: 0.1700
#
# Epoch 00020: val_accuracy improved from 0.15000 to 0.17000, saving model to model_checkpoint_best/chechpoint
# Epoch 21/50
# 10/10 [==============================] - 0s 20ms/step - loss: 1.3250 - accuracy: 0.5857 - val_loss: 2.5047 - val_accuracy: 0.1500
#
# Epoch 00021: val_accuracy did not improve from 0.17000
# Epoch 22/50
# 10/10 [==============================] - 0s 19ms/step - loss: 1.2578 - accuracy: 0.5815 - val_loss: 2.4225 - val_accuracy: 0.1400
#
# Epoch 00022: val_accuracy did not improve from 0.17000
# Epoch 23/50
# 10/10 [==============================] - 0s 19ms/step - loss: 1.1666 - accuracy: 0.6311 - val_loss: 2.4898 - val_accuracy: 0.1700
#
# Epoch 00023: val_accuracy did not improve from 0.17000
# Epoch 24/50
# 10/10 [==============================] - 0s 18ms/step - loss: 1.0086 - accuracy: 0.6534 - val_loss: 2.7423 - val_accuracy: 0.1100
#
# Epoch 00024: val_accuracy did not improve from 0.17000
# Epoch 25/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.9387 - accuracy: 0.7488 - val_loss: 2.6492 - val_accuracy: 0.1600
#
# Epoch 00025: val_accuracy did not improve from 0.17000
# Epoch 26/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.9289 - accuracy: 0.7490 - val_loss: 2.6282 - val_accuracy: 0.1700
#
# Epoch 00026: val_accuracy did not improve from 0.17000
# Epoch 27/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.7057 - accuracy: 0.8573 - val_loss: 2.6917 - val_accuracy: 0.2100
#
# Epoch 00027: val_accuracy improved from 0.17000 to 0.21000, saving model to model_checkpoint_best/chechpoint
# Epoch 28/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.6640 - accuracy: 0.8555 - val_loss: 2.6983 - val_accuracy: 0.2000
#
# Epoch 00028: val_accuracy did not improve from 0.21000
# Epoch 29/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.5938 - accuracy: 0.9132 - val_loss: 3.1226 - val_accuracy: 0.1800
#
# Epoch 00029: val_accuracy did not improve from 0.21000
# Epoch 30/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.5328 - accuracy: 0.8804 - val_loss: 2.8421 - val_accuracy: 0.1800
#
# Epoch 00030: val_accuracy did not improve from 0.21000
# Epoch 31/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.5779 - accuracy: 0.8520 - val_loss: 2.8121 - val_accuracy: 0.2100
#
# Epoch 00031: val_accuracy did not improve from 0.21000
# Epoch 32/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4362 - accuracy: 0.9113 - val_loss: 3.1831 - val_accuracy: 0.2200
#
# Epoch 00032: val_accuracy improved from 0.21000 to 0.22000, saving model to model_checkpoint_best/chechpoint
# Epoch 33/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.3877 - accuracy: 0.9815 - val_loss: 3.1181 - val_accuracy: 0.1700
#
# Epoch 00033: val_accuracy did not improve from 0.22000
# Epoch 34/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.3608 - accuracy: 0.9079 - val_loss: 3.2677 - val_accuracy: 0.1800
#
# Epoch 00034: val_accuracy did not improve from 0.22000
# Epoch 35/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.3442 - accuracy: 0.9363 - val_loss: 3.2294 - val_accuracy: 0.2300
#
# Epoch 00035: val_accuracy improved from 0.22000 to 0.23000, saving model to model_checkpoint_best/chechpoint
# Epoch 36/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2466 - accuracy: 0.9790 - val_loss: 3.3833 - val_accuracy: 0.1800
#
# Epoch 00036: val_accuracy did not improve from 0.23000
# Epoch 37/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.2312 - accuracy: 0.9856 - val_loss: 3.5810 - val_accuracy: 0.2400
#
# Epoch 00037: val_accuracy improved from 0.23000 to 0.24000, saving model to model_checkpoint_best/chechpoint
# Epoch 38/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2039 - accuracy: 0.9982 - val_loss: 3.4992 - val_accuracy: 0.1700
#
# Epoch 00038: val_accuracy did not improve from 0.24000
# Epoch 39/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1514 - accuracy: 0.9861 - val_loss: 3.6645 - val_accuracy: 0.2100
#
# Epoch 00039: val_accuracy did not improve from 0.24000
# Epoch 40/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1697 - accuracy: 0.9891 - val_loss: 3.7459 - val_accuracy: 0.2000
#
# Epoch 00040: val_accuracy did not improve from 0.24000
# Epoch 41/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1044 - accuracy: 0.9891 - val_loss: 3.8009 - val_accuracy: 0.1900
#
# Epoch 00041: val_accuracy did not improve from 0.24000
# Epoch 42/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0846 - accuracy: 1.0000 - val_loss: 4.0146 - val_accuracy: 0.2200
#
# Epoch 00042: val_accuracy did not improve from 0.24000
# Epoch 43/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.1254 - accuracy: 1.0000 - val_loss: 3.9824 - val_accuracy: 0.2000
#
# Epoch 00043: val_accuracy did not improve from 0.24000
# Epoch 44/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0648 - accuracy: 1.0000 - val_loss: 3.9405 - val_accuracy: 0.2300
#
# Epoch 00044: val_accuracy did not improve from 0.24000
# Epoch 45/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0654 - accuracy: 1.0000 - val_loss: 4.2183 - val_accuracy: 0.1600
#
# Epoch 00045: val_accuracy did not improve from 0.24000
# Epoch 46/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0504 - accuracy: 1.0000 - val_loss: 4.1402 - val_accuracy: 0.1800
#
# Epoch 00046: val_accuracy did not improve from 0.24000
# Epoch 47/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0541 - accuracy: 1.0000 - val_loss: 4.2171 - val_accuracy: 0.2000
#
# Epoch 00047: val_accuracy did not improve from 0.24000
# Epoch 48/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0404 - accuracy: 1.0000 - val_loss: 4.3379 - val_accuracy: 0.1900
#
# Epoch 00048: val_accuracy did not improve from 0.24000
# Epoch 49/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0399 - accuracy: 1.0000 - val_loss: 4.3220 - val_accuracy: 0.1500
#
# Epoch 00049: val_accuracy did not improve from 0.24000
# Epoch 50/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0460 - accuracy: 1.0000 - val_loss: 4.4132 - val_accuracy: 0.1800
#
# Epoch 00050: val_accuracy did not improve from 0.24000

# %%
# Plot training and testing curves

import pandas as pd

df = pd.DataFrame(history.history)
df.plot(y=['accuracy', 'val_accuracy'])

# %%
# Inspect the checkpoint directory
# !ls -lh model_checkpoint_best
# Out:
# total 184K
# -rw-r--r-- 1 root root 174K Mar 26 10:35 chechpoint.data-00000-of-00001
# -rw-r--r-- 1 root root 2.0K Mar 26 10:35 chechpoint.index
# -rw-r--r-- 1 root root   77 Mar 26 10:35 checkpoint

# %%
# Create a new model with the saved weights
new_model = get_new_model()
new_model.load_weights(checkpoint_best_path)
get_test_accuracy(new_model, x_test, y_test)
# Out:
# accuracy: 0.240

# %% [markdown]
# #### Clear directory

# %%
! rm -r model_checkpoint_5000 model_checkpoints_best
# Out:
# rm: cannot remove 'model_checkpoint_5000': No such file or directory
# rm: cannot remove 'model_checkpoints_best': No such file or directory

# %% [markdown]
# ***
# <a id="coding_tutorial_3"></a>
# ## Saving the entire model

# %% [markdown]
# #### Create checkpoint that saves whole model, not just weights

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# Create Tensorflow checkpoint object
checkpoint_path = 'model_checkpoints'
checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                             save_weights_only=False,
                             save_freq='epoch',
                             verbose=1)

# %%
# Create and fit model with checkpoint
model = get_new_model()
model.fit(x_train, y_train,
          epochs=3,
          callbacks=[checkpoint])
# Out:
# Epoch 1/3
# 313/313 [==============================] - 11s 33ms/step - loss: 2.1108 - accuracy: 0.2093
#
# Epoch 00001: saving model to model_checkpoints
# INFO:tensorflow:Assets written to: model_checkpoints/assets
# Epoch 2/3
# 313/313 [==============================] - 10s 33ms/step - loss: 1.6812 - accuracy: 0.3884
#
# Epoch 00002: saving model to model_checkpoints
# INFO:tensorflow:Assets written to: model_checkpoints/assets
# Epoch 3/3
# 313/313 [==============================] - 10s 33ms/step - loss: 1.5409 - accuracy: 0.4498
#
# Epoch 00003: saving model to model_checkpoints
# INFO:tensorflow:Assets written to: model_checkpoints/assets

# %% [markdown]
# #### Inspect what the checkpoint has created

# %%
# Have a look at what the checkpoint creates
# !ls -lh model_checkpoints
# Out:
# total 136K
# drwxr-xr-x 2 root root 4.0K Mar 28 07:01 assets
# -rw-r--r-- 1 root root 126K Mar 28 07:01 saved_model.pb
# drwxr-xr-x 2 root root 4.0K Mar 28 07:01 variables

# %%
# Enter variables directory
# !ls -lh model_checkpoints/variables/
# Out:
# total 184K
# -rw-r--r-- 1 root root 177K Mar 28 07:01 variables.data-00000-of-00001
# -rw-r--r-- 1 root root 2.2K Mar 28 07:01 variables.index

# %%
# Get the model's test accuracy
get_test_accuracy(model, x_test, y_test)
# Out:
# accuracy: 0.441

# %% [markdown]
# #### Create new model from scratch

# %%
# Delete model
del model

# %%
from tensorflow.keras.models import load_model

# %%
# Reload model from scratch
model = load_model(checkpoint_path)
get_test_accuracy(model, x_test, y_test)
# Out:
# accuracy: 0.441

# %% [markdown]
# #### Use the .h5 format to save model

# %%
# Save the model in .h5 format
model.save('my_model.h5')

# %%
# Inspect .h5 file
# !ls -lh my_model.h5
# Out:
# -rw-r--r-- 1 root root 77K Mar 28 07:02 my_model.h5

# %%
# Delete model
del model

# %%
# Reload model from scratch
model = load_model('my_model.h5')
get_test_accuracy(model, x_test, y_test)
# Out:
# accuracy: 0.441

# %% [markdown]
# #### Clear directory

# %%
! rm -r model_checkpoints
! rm my_model.h5

# %% [markdown]
# ***
# <a id="coding_tutorial_4"></a>
# ## Loading pre-trained Keras models

# %% [markdown]
# #### Import and build Keras ResNet50 model
#
# Today we'll be using the ResNet50 model designed by a team at Microsoft Research, available through Keras applications. Please see the description on the [Keras applications page](https://keras.io/applications/#resnet) for details. If you continue using it, please cite it properly! The paper it comes from is:
#
# Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun. "Deep Residual Learning for Image Recognition", 2015.
#
# In the coding tutorial on Coursera, this model is loaded directly from disk. On Colab, you will load the model using the Keras API.

# %%
from tensorflow.keras.applications import ResNet50
model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102973440/102967424 [==============================] - 1s 0us/step

# %% [markdown]
# #### Import and preprocess 3 sample images

# %%
# Retrieve the image files

# !wget -q -O lemon.jpg --no-check-certificate "https://docs.google.com/uc?export=download&id=1JSgQ9qgi9nO9t2aGEk-zA6lzYNUT9vZJ"
# !wget -q -O viaduct.jpg --no-check-certificate "https://docs.google.com/uc?export=download&id=1sQzMKmyCR5Tur19lP3n1IIlEMG_o6Mct"
# !wget -q -O water_tower.jpg --no-check-certificate "https://docs.google.com/uc?export=download&id=1cPAQD1O6mAiMbg0fmG5HIk8OuO_BSC6J"

# %%
# Import 3 sample ImageNet images

from tensorflow.keras.preprocessing.image import load_img

lemon_img = load_img('lemon.jpg', target_size=(224, 224))
viaduct_img = load_img('viaduct.jpg', target_size=(224, 224))
water_tower_img = load_img('water_tower.jpg', target_size=(224, 224))

# %% [markdown]
# #### Use ResNet50 model to classify images

# %%
# Useful function: presents top 5 predictions and probabilities

from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
import pandas as pd

def get_top_5_predictions(img):
    x = img_to_array(img)[np.newaxis, ...]
    x = preprocess_input(x)
    preds = decode_predictions(model.predict(x), top=5)
    top_preds = pd.DataFrame(columns=['prediction', 'probability'],
                             index=np.arange(5)+1)
    for i in range(5):
        top_preds.loc[i+1, 'prediction'] = preds[0][i][1]
        top_preds.loc[i+1, 'probability'] = preds[0][i][2] 
    return top_preds

# %% [markdown]
# ##### Image 1: lemon

# %%
# Display image
lemon_img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F933E7C2850>

# %%
# Display top 5 predictions
get_top_5_predictions(lemon_img)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step
#   prediction probability
# 1   consomme    0.227801
# 2      lemon    0.221758
# 3     eggnog    0.151335
# 4      ladle   0.0400882
# 5  spotlight   0.0291972

# %% [markdown]
# ##### Image 2: viaduct

# %%
# Display image
viaduct_img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F933E794790>

# %%
# Display top 5 predictions
get_top_5_predictions(viaduct_img)
# Out:
#       prediction probability
# 1          vault    0.367951
# 2         prison    0.111742
# 3        viaduct    0.110737
# 4  window_screen   0.0882308
# 5    fire_screen   0.0206752

# %% [markdown]
# ##### Image 3: water tower

# %%
# Display image
water_tower_img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F933E798D10>

# %%
# Display top 5 predictions
get_top_5_predictions(water_tower_img)
# Out:
#       prediction probability
# 1     solar_dish    0.384682
# 2          ladle    0.196178
# 3    planetarium    0.116682
# 4       strainer   0.0499899
# 5  jigsaw_puzzle   0.0219474

# %% [markdown]
# ***
# <a id="coding_tutorial_5"></a>
# ## Tensorflow Hub modules

# %% [markdown]
# #### Import and build Tensorflow Hub MobileNet v1 model
#
# Today we'll be using Google's MobileNet v1 model, available on Tensorflow Hub. Please see the description on the [Tensorflow Hub page](https://tfhub.dev/google/imagenet/mobilenet_v1_050_160/classification/4) for details on it's architecture, how it's trained, and the reference. If you continue using it, please cite it properly! The paper it comes from is:
#
# Andrew G. Howard, Menglong Zhu, Bo Chen, Dmitry Kalenichenko, Weijun Wang, Tobias Weyand, Marco Andreetto, Hartwig Adam: "MobileNets: Efficient Convolutional Neural Networks for Mobile Vision Applications", 2017.
#
# In the coding tutorial on Coursera, this model is loaded directly from disk. On Colab, you will load the model from TensorFlow Hub.

# %%
import tensorflow_hub as hub

# %%
# Build Google's Mobilenet v1 model

module_url = "https://tfhub.dev/google/imagenet/mobilenet_v1_050_160/classification/4"
model = Sequential([hub.KerasLayer(module_url)])
model.build(input_shape=[None, 160, 160, 3])

# %% [markdown]
# #### Use MobileNet model to classify images

# %%
# Retrieve the image files

# !wget -q -O lemon.jpg --no-check-certificate "https://docs.google.com/uc?export=download&id=1JSgQ9qgi9nO9t2aGEk-zA6lzYNUT9vZJ"
# !wget -q -O viaduct.jpg --no-check-certificate "https://docs.google.com/uc?export=download&id=1sQzMKmyCR5Tur19lP3n1IIlEMG_o6Mct"
# !wget -q -O water_tower.jpg --no-check-certificate "https://docs.google.com/uc?export=download&id=1cPAQD1O6mAiMbg0fmG5HIk8OuO_BSC6J"

# %%
# Import and preprocess 3 sample ImageNet images

from tensorflow.keras.preprocessing.image import load_img

lemon_img = load_img("lemon.jpg", target_size=(160, 160))
viaduct_img = load_img("viaduct.jpg", target_size=(160, 160))
water_tower_img = load_img("water_tower.jpg", target_size=(160, 160))

# %%
# Out:
# lemon.jpg  sample_data	viaduct.jpg  water_tower.jpg

# %%
# Read in categories text file

with open('data/imagenet_categories.txt') as txt_file:
    categories = txt_file.read().splitlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-c140396aeaaf> in <module>()
#       1 # Read in categories text file
#       2
# ----> 3 with open('data/imagenet_categories.txt') as txt_file:
#       4     categories = txt_file.read().splitlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/imagenet_categories.txt'

# %%
# Useful function: presents top 5 predictions

import pandas as pd

def get_top_5_predictions(img):
    x = img_to_array(img)[np.newaxis, ...] / 255.0
    preds = model.predict(x)
    top_preds = pd.DataFrame(columns=['prediction'],
                             index=np.arange(5)+1)
    sorted_index = np.argsort(-preds[0])
    for i in range(5):
        ith_pred = categories[sorted_index[i]]
        top_preds.loc[i+1, 'prediction'] = ith_pred
            
    return top_preds

# %% [markdown]
# ##### Image 1: lemon

# %%
lemon_img
# Out:
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7FD09D7A4E90>

# %%
get_top_5_predictions(lemon_img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-b315f39535a5> in <module>()
# ----> 1 get_top_5_predictions(lemon_img)
#
# <ipython-input-17-1372ef8acab2> in get_top_5_predictions(img)
#       9     x = img_to_array(img)[np.newaxis, ...]
#      10     x = preprocess_input(x)
# ---> 11     preds = decode_predictions(model.predict(x), top=5)
#      12     top_preds = pd.DataFrame(columns=['prediction', 'probability'],
#      13                              index=np.arange(5)+1)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/applications/resnet.py in decode_predictions(preds, top)
#     525               'keras.applications.resnet.decode_predictions')
#     526 def decode_predictions(preds, top=5):
# --> 527   return imagenet_utils.decode_predictions(preds, top=top)
#     528
#     529
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/applications/imagenet_utils.py in decode_predictions(preds, top)
#     149                      'a batch of predictions '
#     150                      '(i.e. a 2D array of shape (samples, 1000)). '
# --> 151                      'Found array with shape: ' + str(preds.shape))
#     152   if CLASS_INDEX is None:
#     153     fpath = data_utils.get_file(
#
# ValueError: `decode_predictions` expects a batch of predictions (i.e. a 2D array of shape (samples, 1000)). Found array with shape: (1, 1001)

# %% [markdown]
# ##### Image 2: viaduct

# %%
viaduct_img
# Out:
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7FD09D6FFE10>

# %%
get_top_5_predictions(viaduct_img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-f28885519e35> in <module>()
# ----> 1 get_top_5_predictions(viaduct_img)
#
# <ipython-input-17-1372ef8acab2> in get_top_5_predictions(img)
#       9     x = img_to_array(img)[np.newaxis, ...]
#      10     x = preprocess_input(x)
# ---> 11     preds = decode_predictions(model.predict(x), top=5)
#      12     top_preds = pd.DataFrame(columns=['prediction', 'probability'],
#      13                              index=np.arange(5)+1)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/applications/resnet.py in decode_predictions(preds, top)
#     525               'keras.applications.resnet.decode_predictions')
#     526 def decode_predictions(preds, top=5):
# --> 527   return imagenet_utils.decode_predictions(preds, top=top)
#     528
#     529
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/applications/imagenet_utils.py in decode_predictions(preds, top)
#     149                      'a batch of predictions '
#     150                      '(i.e. a 2D array of shape (samples, 1000)). '
# --> 151                      'Found array with shape: ' + str(preds.shape))
#     152   if CLASS_INDEX is None:
#     153     fpath = data_utils.get_file(
#
# ValueError: `decode_predictions` expects a batch of predictions (i.e. a 2D array of shape (samples, 1000)). Found array with shape: (1, 1001)

# %% [markdown]
# ##### Image 3: water tower
